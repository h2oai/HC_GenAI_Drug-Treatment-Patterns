# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /var/folders/3m/l0tyzx5j5lg1wtczpcc3ff8h0000gn/T/ipykernel_98677/1782674290.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('alopecia-areata-subsample/ENCOUNTERS/data_000000000000.csv',  delimiter="|")

# %%
data.shape
# Out:
# (10615, 42)

# %%
data.head()
# Out:
#                              PATIENT_ID                          ENCOUNTER_ID  \
# 0  1F53ACFE-2818-45BB-95C9-3D4AF7B2E87A  1374D103-4503-49EB-AA9D-DE13ECD84DB2
# 1  6E9B5113-3510-4DC9-BA45-70E8C8AB15D1  F897D53A-43CA-47CB-BD24-4FD0CAB5A74D
# 2  4DB344AF-FF79-4BC2-98F3-A13F7EDF45B0  9CE29B97-F51C-4567-AD8A-844390C06C2D
# 3  96E8E86A-C6A9-4C36-BE45-125A8C299458  0FFE66C0-C0E8-48F0-99F6-00A915488596
# 4  8703777E-3F68-43B4-BBAF-2BD773E06CED  14517F63-6264-4666-BA48-9B0253AEAC0D
#
#   EN_START_DATE EN_START_TIME EN_END_DATE EN_END_TIME  EN_LOS EN_FACILITY  \
# 0    2023-04-24      15:19:58  2023-04-24         NaN     NaN         NaN
# 1    2021-03-12      15:26:30  2021-03-12         NaN     NaN         NaN
# 2    2017-02-10      17:40:41  2017-02-10         NaN     NaN         NaN
# 3    2023-03-31      21:16:14  2023-03-31         NaN     NaN         NaN
# 4    2021-09-01      17:10:38  2021-09-01         NaN     NaN         NaN
#
# ...

# %%
data.tail()
# Out:
#                                  PATIENT_ID  \
# 10610  502DCB86-3801-4658-8B5B-284FF484A72C
# 10611  DE891A90-48EB-410C-A451-429020B4C85F
# 10612  DE891A90-48EB-410C-A451-429020B4C85F
# 10613  46B2BC4B-0B97-4C86-ABEE-9993CB250B80
# 10614  279BB8DB-6ABE-4F95-AEE1-60BF98C2FE60
#
#                                ENCOUNTER_ID EN_START_DATE EN_START_TIME  \
# 10610  42BFBD19-16DB-46B2-A569-77B2A811D030    2021-08-11      14:23:00
# 10611  67AC20EF-BC84-4F7F-BF41-14D493071AA1    2022-11-22      14:00:00
# 10612  20E23129-EF98-493E-A199-3A46658FCFFF    2019-07-29      14:00:00
# 10613  89C16BDD-6F3E-453A-9775-03987AA9A585    2023-09-19      21:30:00
# 10614  5162698B-5988-4A8A-AAAD-5C847DB3C362    2018-12-21      22:46:00
#
#       EN_END_DATE EN_END_TIME  EN_LOS  \
# 10610  2021-08-11    14:23:00     NaN
# 10611  2022-11-22    14:00:00     NaN
# 10612  2019-07-29    20:48:58     NaN
# 10613  2023-09-20    23:31:31     NaN
# 10614  2018-12-22    02:48:08     NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10615 entries, 0 to 10614
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         10615 non-null  object
#  1   ENCOUNTER_ID       10615 non-null  object
#  2   EN_START_DATE      10615 non-null  object
#  3   EN_START_TIME      10615 non-null  object
#  4   EN_END_DATE        10615 non-null  object
#  5   EN_END_TIME        8999 non-null   object
#  6   EN_LOS             1 non-null      float64
#  7   EN_FACILITY        7876 non-null   object
#  8   EN_FACILITY_TYPE   6207 non-null   object
#  9   EN_URBAN_RURAL     8920 non-null   object
#  10  EN_FACILITY_SIZE   365 non-null    object
#  11  EN_DEPT            7870 non-null   object
#  12  EN_ADM_DEPT        3 non-null      object
#  13  EN_DC_DEPT         3 non-null      object
#  14  EN_PCP_PROV_ID     8780 non-null   object
#  15  EN_PCP_PROV_TAXON  8773 non-null   object
# ...

# %% [markdown]
# ## Checking for Duplication

# %%
data.nunique()
# Out:
# PATIENT_ID            1000
# ENCOUNTER_ID         10614
# EN_START_DATE         1736
# EN_START_TIME         2585
# EN_END_DATE           1888
# EN_END_TIME           6233
# EN_LOS                   1
# EN_FACILITY            333
# EN_FACILITY_TYPE         4
# EN_URBAN_RURAL           3
# EN_FACILITY_SIZE         2
# EN_DEPT                363
# EN_ADM_DEPT              3
# EN_DC_DEPT               3
# EN_PCP_PROV_ID         879
# EN_PCP_PROV_TAXON       16
# EN_PR_PROV_ID          872
# EN_PR_PROV_TAXON        15
# EN_ADM_PROV_ID           0
# EN_ADM_PROV_TAXON        0
# EN_ATT_PROV_ID           9
# EN_ATT_PROV_TAXON        5
# EN_DC_PROV_ID            7
# EN_DC_PROV_TAXON         5
# EN_TYPE                 72
# EN_SETTING_DET           8
# EN_SETTING               5
# EN_ADM_TYPE             56
# EN_DC_DIS                1
# EN_MS_DRG_CODE           0
# EN_AP_DRG_CODE           0
# EN_GROSS_CHARGES        75
# EN_REIMBURSED           67
# EMPLOY                   5
# ...

# %%
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [PATIENT_ID, ENCOUNTER_ID, EN_START_DATE, EN_START_TIME, EN_END_DATE, EN_END_TIME, EN_LOS, EN_FACILITY, EN_FACILITY_TYPE, EN_URBAN_RURAL, EN_FACILITY_SIZE, EN_DEPT, EN_ADM_DEPT, EN_DC_DEPT, EN_PCP_PROV_ID, EN_PCP_PROV_TAXON, EN_PR_PROV_ID, EN_PR_PROV_TAXON, EN_ADM_PROV_ID, EN_ADM_PROV_TAXON, EN_ATT_PROV_ID, EN_ATT_PROV_TAXON, EN_DC_PROV_ID, EN_DC_PROV_TAXON, EN_TYPE, EN_SETTING_DET, EN_SETTING, EN_ADM_TYPE, EN_DC_DIS, EN_MS_DRG_CODE, EN_AP_DRG_CODE, EN_GROSS_CHARGES, EN_REIMBURSED, EMPLOY, RACE, ETHNICITY, GENDER, AGE, DATA_SUPPLIER_ID, PRODUCT_NAME, PRODUCT_VERSION, EXPORT_DATE]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# No duplicate rows found in the dataset

# %% [markdown]
# ## Checking Missing Values

# %%
data.isnull().sum()
# Out:
# PATIENT_ID               0
# ENCOUNTER_ID             0
# EN_START_DATE            0
# EN_START_TIME            0
# EN_END_DATE              0
# EN_END_TIME           1616
# EN_LOS               10614
# EN_FACILITY           2739
# EN_FACILITY_TYPE      4408
# EN_URBAN_RURAL        1695
# EN_FACILITY_SIZE     10250
# EN_DEPT               2745
# EN_ADM_DEPT          10612
# EN_DC_DEPT           10612
# EN_PCP_PROV_ID        1835
# EN_PCP_PROV_TAXON     1842
# EN_PR_PROV_ID         2228
# EN_PR_PROV_TAXON      2235
# EN_ADM_PROV_ID       10615
# EN_ADM_PROV_TAXON    10615
# EN_ATT_PROV_ID       10602
# EN_ATT_PROV_TAXON    10602
# EN_DC_PROV_ID        10607
# EN_DC_PROV_TAXON     10607
# EN_TYPE                  0
# EN_SETTING_DET           0
# EN_SETTING               0
# EN_ADM_TYPE          10175
# EN_DC_DIS            10614
# EN_MS_DRG_CODE       10615
# EN_AP_DRG_CODE       10615
# EN_GROSS_CHARGES     10469
# EN_REIMBURSED        10469
# EMPLOY                   0
# ...

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# PATIENT_ID             0.000000
# ENCOUNTER_ID           0.000000
# EN_START_DATE          0.000000
# EN_START_TIME          0.000000
# EN_END_DATE            0.000000
# EN_END_TIME           15.223740
# EN_LOS                99.990579
# EN_FACILITY           25.803109
# EN_FACILITY_TYPE      41.526142
# EN_URBAN_RURAL        15.967970
# EN_FACILITY_SIZE      96.561470
# EN_DEPT               25.859633
# EN_ADM_DEPT           99.971738
# EN_DC_DEPT            99.971738
# EN_PCP_PROV_ID        17.286858
# EN_PCP_PROV_TAXON     17.352803
# EN_PR_PROV_ID         20.989166
# EN_PR_PROV_TAXON      21.055111
# EN_ADM_PROV_ID       100.000000
# EN_ADM_PROV_TAXON    100.000000
# EN_ATT_PROV_ID        99.877532
# EN_ATT_PROV_TAXON     99.877532
# EN_DC_PROV_ID         99.924635
# EN_DC_PROV_TAXON      99.924635
# EN_TYPE                0.000000
# EN_SETTING_DET         0.000000
# EN_SETTING             0.000000
# EN_ADM_TYPE           95.854922
# EN_DC_DIS             99.990579
# ...

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# No need to  include IDs and code (Most of the data is missing)
#
# Data Has Many Missing Values ! need to drop the column with all NaN values
#
#
# Columns               Percentage of missing values
#
# EN_END_TIME           15.223740
# EN_LOS                99.990579
# EN_FACILITY           25.803109
# EN_FACILITY_TYPE      41.526142
# EN_URBAN_RURAL        15.967970
# EN_DEPT               25.859633
# EN_ADM_DEPT           99.971738
# EN_DC_DEPT            99.971738
# EN_PCP_PROV_TAXON     17.352803
# EN_PR_PROV_TAXON      21.055111
# EN_ADM_PROV_TAXON    100.000000
# EN_ATT_PROV_TAXON     99.877532
# EN_DC_PROV_TAXON      99.924635
# EN_ADM_TYPE           95.854922
# EN_DC_DIS             99.990579
# EN_GROSS_CHARGES      98.624588
# EN_REIMBURSED         98.624588
# GENDER                 0.047103

# %% [markdown]
# ## Checking for inconsistent data types

# %%
data_types = data.dtypes
print(data_types)
# Out:
# PATIENT_ID            object
# ENCOUNTER_ID          object
# EN_START_DATE         object
# EN_START_TIME         object
# EN_END_DATE           object
# EN_END_TIME           object
# EN_LOS               float64
# EN_FACILITY           object
# EN_FACILITY_TYPE      object
# EN_URBAN_RURAL        object
# EN_FACILITY_SIZE      object
# EN_DEPT               object
# EN_ADM_DEPT           object
# EN_DC_DEPT            object
# EN_PCP_PROV_ID        object
# EN_PCP_PROV_TAXON     object
# EN_PR_PROV_ID         object
# EN_PR_PROV_TAXON      object
# EN_ADM_PROV_ID       float64
# EN_ADM_PROV_TAXON    float64
# EN_ATT_PROV_ID        object
# EN_ATT_PROV_TAXON     object
# EN_DC_PROV_ID         object
# EN_DC_PROV_TAXON      object
# EN_TYPE               object
# EN_SETTING_DET        object
# EN_SETTING            object
# EN_ADM_TYPE           object
# EN_DC_DIS             object
# EN_MS_DRG_CODE       float64
# EN_AP_DRG_CODE       float64
# EN_GROSS_CHARGES     float64
# ...
