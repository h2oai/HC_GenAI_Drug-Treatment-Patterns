# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /var/folders/3m/l0tyzx5j5lg1wtczpcc3ff8h0000gn/T/ipykernel_130/3993962526.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('alopecia-areata-subsample/PRESCRIPTION_ADMINISTRATIONS/data_000000000000.csv',  delimiter="|")

# %%
data.shape
# Out:
# (143, 26)

# %% [markdown]
# Small dataset - 143 rows

# %%
data.head()
# Out:
#                              PATIENT_ID                          ENCOUNTER_ID  \
# 0  9E62A2DC-8195-4E37-BBE4-D0D68274E40B  8FD3C7C9-107B-4C6F-8344-41522C44AABE
# 1  9E62A2DC-8195-4E37-BBE4-D0D68274E40B  9FB0E78D-EEFF-4964-A7FA-17F0A3ACC4E2
# 2  9E62A2DC-8195-4E37-BBE4-D0D68274E40B  D502AFB9-FC2A-4B66-826D-FAB37C0E88E9
# 3  9E62A2DC-8195-4E37-BBE4-D0D68274E40B  8FD3C7C9-107B-4C6F-8344-41522C44AABE
# 4  50D1CB9B-E684-48C7-AC5F-706AB3DB3440  0F43D31C-C95E-4D7A-9E5D-C9D5CCB1E13A
#
#   AD_ADMIN_DATE AD_ADMIN_TIME                                 AD_FACILITY  \
# 0    2021-10-10      13:04:00  SMALL URBAN - METROPOLITAN AREA HOSPITAL 1
# 1    2022-11-07      10:02:00  SMALL URBAN - METROPOLITAN AREA HOSPITAL 1
# 2    2022-05-09      09:46:00  SMALL URBAN - METROPOLITAN AREA HOSPITAL 1
# 3    2021-10-10      12:42:00  SMALL URBAN - METROPOLITAN AREA HOSPITAL 1
# 4    2020-10-06      10:49:00  LARGE URBAN - METROPOLITAN AREA HOSPITAL 1
#
# ...

# %%
data.tail()
# Out:
#                                PATIENT_ID  \
# 138  50D1CB9B-E684-48C7-AC5F-706AB3DB3440
# 139  50D1CB9B-E684-48C7-AC5F-706AB3DB3440
# 140  50D1CB9B-E684-48C7-AC5F-706AB3DB3440
# 141  50D1CB9B-E684-48C7-AC5F-706AB3DB3440
# 142  9E62A2DC-8195-4E37-BBE4-D0D68274E40B
#
#                              ENCOUNTER_ID AD_ADMIN_DATE AD_ADMIN_TIME  \
# 138  0F43D31C-C95E-4D7A-9E5D-C9D5CCB1E13A    2020-10-06      10:49:00
# 139  4D0466AD-4486-4EEF-B19B-36C08332C6C3    2019-05-10      09:51:00
# 140  4D0466AD-4486-4EEF-B19B-36C08332C6C3    2019-05-10      03:56:00
# 141  0F43D31C-C95E-4D7A-9E5D-C9D5CCB1E13A    2020-10-06      11:05:00
# 142  2CD68756-C4DC-4AF6-84FC-410757DB7998    2022-04-18      09:53:00
#
#                                     AD_FACILITY AD_FACILITY_TYPE  \
# 138  LARGE URBAN - METROPOLITAN AREA HOSPITAL 1         HOSPITAL
# 139  LARGE URBAN - METROPOLITAN AREA HOSPITAL 1         HOSPITAL
# 140  LARGE URBAN - METROPOLITAN AREA HOSPITAL 1         HOSPITAL
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         143 non-null    object
#  1   ENCOUNTER_ID       143 non-null    object
#  2   AD_ADMIN_DATE      143 non-null    object
#  3   AD_ADMIN_TIME      143 non-null    object
#  4   AD_FACILITY        141 non-null    object
#  5   AD_FACILITY_TYPE   141 non-null    object
#  6   AD_URBAN_RURAL     2 non-null      object
#  7   AD_FACILITY_SIZE   141 non-null    object
#  8   AD_DEPT            141 non-null    object
#  9   AD_HCS_BRAND_NAME  0 non-null      float64
#  10  AD_DOSE_TOTAL      138 non-null    float64
#  11  AD_DOSE_UNIT       141 non-null    object
#  12  AD_ADMIN_ROUTE     143 non-null    object
#  13  AD_PKG_DESC        128 non-null    object
#  14  AD_NDC             137 non-null    object
#  15  AD_LABELER         137 non-null    object
# ...

# %% [markdown]
# ## Checking for Duplication

# %%
data.nunique()
# Out:
# PATIENT_ID            5
# ENCOUNTER_ID         41
# AD_ADMIN_DATE        35
# AD_ADMIN_TIME        95
# AD_FACILITY           2
# AD_FACILITY_TYPE      1
# AD_URBAN_RURAL        1
# AD_FACILITY_SIZE      2
# AD_DEPT              11
# AD_HCS_BRAND_NAME     0
# AD_DOSE_TOTAL        50
# AD_DOSE_UNIT         11
# AD_ADMIN_ROUTE       12
# AD_PKG_DESC          65
# AD_NDC               65
# AD_LABELER           44
# AD_BRAND_NAME        57
# AD_GENERIC_NAME      55
# AD_ROUTE             16
# AD_STRENGTH          33
# AD_UNIT              19
# AD_DOSE_FORM         21
# DATA_SUPPLIER_ID      3
# PRODUCT_NAME          1
# PRODUCT_VERSION       1
# EXPORT_DATE           1
# dtype: int64

# %%
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [PATIENT_ID, ENCOUNTER_ID, AD_ADMIN_DATE, AD_ADMIN_TIME, AD_FACILITY, AD_FACILITY_TYPE, AD_URBAN_RURAL, AD_FACILITY_SIZE, AD_DEPT, AD_HCS_BRAND_NAME, AD_DOSE_TOTAL, AD_DOSE_UNIT, AD_ADMIN_ROUTE, AD_PKG_DESC, AD_NDC, AD_LABELER, AD_BRAND_NAME, AD_GENERIC_NAME, AD_ROUTE, AD_STRENGTH, AD_UNIT, AD_DOSE_FORM, DATA_SUPPLIER_ID, PRODUCT_NAME, PRODUCT_VERSION, EXPORT_DATE]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No duplicate rows found in the dataset

# %% [markdown]
# ## Checking Missing Values

# %%
data.isnull().sum()
# Out:
# PATIENT_ID             0
# ENCOUNTER_ID           0
# AD_ADMIN_DATE          0
# AD_ADMIN_TIME          0
# AD_FACILITY            2
# AD_FACILITY_TYPE       2
# AD_URBAN_RURAL       141
# AD_FACILITY_SIZE       2
# AD_DEPT                2
# AD_HCS_BRAND_NAME    143
# AD_DOSE_TOTAL          5
# AD_DOSE_UNIT           2
# AD_ADMIN_ROUTE         0
# AD_PKG_DESC           15
# AD_NDC                 6
# AD_LABELER             6
# AD_BRAND_NAME          6
# AD_GENERIC_NAME        6
# AD_ROUTE              17
# AD_STRENGTH            7
# AD_UNIT                7
# AD_DOSE_FORM           7
# DATA_SUPPLIER_ID       0
# PRODUCT_NAME           0
# PRODUCT_VERSION        0
# EXPORT_DATE            0
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# PATIENT_ID             0.000000
# ENCOUNTER_ID           0.000000
# AD_ADMIN_DATE          0.000000
# AD_ADMIN_TIME          0.000000
# AD_FACILITY            1.398601
# AD_FACILITY_TYPE       1.398601
# AD_URBAN_RURAL        98.601399
# AD_FACILITY_SIZE       1.398601
# AD_DEPT                1.398601
# AD_HCS_BRAND_NAME    100.000000
# AD_DOSE_TOTAL          3.496503
# AD_DOSE_UNIT           1.398601
# AD_ADMIN_ROUTE         0.000000
# AD_PKG_DESC           10.489510
# AD_NDC                 4.195804
# AD_LABELER             4.195804
# AD_BRAND_NAME          4.195804
# AD_GENERIC_NAME        4.195804
# AD_ROUTE              11.888112
# AD_STRENGTH            4.895105
# AD_UNIT                4.895105
# AD_DOSE_FORM           4.895105
# DATA_SUPPLIER_ID       0.000000
# PRODUCT_NAME           0.000000
# PRODUCT_VERSION        0.000000
# EXPORT_DATE            0.000000
# dtype: float64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Data Has some Missing Values ! need to drop the column with all NaN values - AD_HCS_BRAND_NAME, AD_URBAN_RURAL

# %% [markdown]
# ## Checking for inconsistent data types

# %%
data_types = data.dtypes
print(data_types)
# Out:
# PATIENT_ID            object
# ENCOUNTER_ID          object
# AD_ADMIN_DATE         object
# AD_ADMIN_TIME         object
# AD_FACILITY           object
# AD_FACILITY_TYPE      object
# AD_URBAN_RURAL        object
# AD_FACILITY_SIZE      object
# AD_DEPT               object
# AD_HCS_BRAND_NAME    float64
# AD_DOSE_TOTAL        float64
# AD_DOSE_UNIT          object
# AD_ADMIN_ROUTE        object
# AD_PKG_DESC           object
# AD_NDC                object
# AD_LABELER            object
# AD_BRAND_NAME         object
# AD_GENERIC_NAME       object
# AD_ROUTE              object
# AD_STRENGTH           object
# AD_UNIT               object
# AD_DOSE_FORM          object
# DATA_SUPPLIER_ID       int64
# PRODUCT_NAME          object
# PRODUCT_VERSION      float64
# EXPORT_DATE            int64
# dtype: object
