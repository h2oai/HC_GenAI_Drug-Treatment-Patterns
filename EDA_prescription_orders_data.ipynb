# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /var/folders/3m/l0tyzx5j5lg1wtczpcc3ff8h0000gn/T/ipykernel_1700/1676706666.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('alopecia-areata-subsample/PRESCRIPTION_ORDERS/data_000000000000.csv',  delimiter="|")

# %%
data.shape
# Out:
# (6389, 38)

# %%
data.head()
# Out:
#                              PATIENT_ID                          ENCOUNTER_ID  \
# 0  31A6009B-0FA3-44AB-9E14-A7B0AD3CD3E6  3846AAEF-8E76-455A-BB41-642DE081B9A3
# 1  B9AD96A2-7BC7-4DCE-8D8C-F3747A1923EF  0A4E37B9-4F5E-4F19-BBA1-FAC5B9CA058A
# 2  B9CEB656-E66C-44B9-ABD1-C1D88BE61159  7DB3A5E4-86AB-4357-BF66-AB66FE92CD87
# 3  E384DA67-0959-4491-B4DA-1A3054CF7E31  CB6D7279-B512-46F8-89E0-F53641037134
# 4  BBABB462-F911-4782-AF1E-D9549CFA7158  5933A0CD-2D4D-469E-80F3-15083C1EDA04
#
#   RX_ORDER_DATE RX_ORDER_TIME                                 RX_FACILITY  \
# 0    2020-06-18      19:03:37         URBAN - METROPOLITAN AREA CLINIC 95
# 1    2021-04-20      00:00:00  LARGE URBAN - METROPOLITAN AREA HOSPITAL 1
# 2    2020-01-28      14:54:34         URBAN - METROPOLITAN AREA CLINIC 39
# 3    2020-03-04      22:02:31         URBAN - METROPOLITAN AREA CLINIC 49
# 4    2021-01-20      14:22:54      URBAN - NONMETROPOLITAN AREA CLINIC 54
#
#   RX_FACILITY_TYPE                RX_URBAN_RURAL RX_FACILITY_SIZE  \
# 0           CLINIC     URBAN - METROPOLITAN AREA              NaN
# 1         HOSPITAL                           NaN            LARGE
# 2           CLINIC     URBAN - METROPOLITAN AREA              NaN
# 3           CLINIC     URBAN - METROPOLITAN AREA              NaN
# 4              NaN  URBAN - NONMETROPOLITAN AREA              NaN
#
#                                   RX_DEPT        RX_PROV_TAXON  ...  \
# 0     URBAN - METROPOLITAN AREA CLINIC 95  PHYSICIAN ASSISTANT  ...
# 1                      EMERGENCY MEDICINE   NURSE PRACTITIONER  ...
# 2     URBAN - METROPOLITAN AREA CLINIC 39          DERMATOLOGY  ...
# 3     URBAN - METROPOLITAN AREA CLINIC 49  PHYSICIAN ASSISTANT  ...
# 4  URBAN - NONMETROPOLITAN AREA CLINIC 54          DERMATOLOGY  ...
#
#   RX_BRAND_NAME RX_GENERIC_NAME RX_ROUTE RX_STRENGTH  RX_UNIT RX_DOSE_FORM  \
# 0           NaN             NaN      NaN         NaN      NaN          NaN
# 1           NaN             NaN      NaN         NaN      NaN          NaN
# 2           NaN             NaN      NaN         NaN      NaN          NaN
# 3           NaN             NaN      NaN         NaN      NaN          NaN
# 4           NaN             NaN      NaN         NaN      NaN          NaN
#
#    DATA_SUPPLIER_ID                                   PRODUCT_NAME  \
# 0              8669  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS
# 1              9688  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS
# 2              8551  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS
# 3              6808  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS
# 4              4632  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS
#
#    PRODUCT_VERSION EXPORT_DATE
# 0              5.0    20231213
# 1              5.0    20231213
# 2              5.0    20231213
# 3              5.0    20231213
# 4              5.0    20231213
#
# [5 rows x 38 columns]

# %%
data.tail()
# Out:
#                                 PATIENT_ID  \
# 6384  502DCB86-3801-4658-8B5B-284FF484A72C
# 6385  502DCB86-3801-4658-8B5B-284FF484A72C
# 6386  502DCB86-3801-4658-8B5B-284FF484A72C
# 6387  502DCB86-3801-4658-8B5B-284FF484A72C
# 6388  502DCB86-3801-4658-8B5B-284FF484A72C
#
#                               ENCOUNTER_ID RX_ORDER_DATE RX_ORDER_TIME  \
# 6384  2C3F7AB0-D008-45A4-81A9-E92D9249010B    2020-09-20      01:52:30
# 6385  2C3F7AB0-D008-45A4-81A9-E92D9249010B    2020-09-20      00:58:32
# 6386  18894574-46EB-40E0-ADDB-D391A953459A    2020-09-20      00:58:32
# 6387  18894574-46EB-40E0-ADDB-D391A953459A    2020-09-20      01:24:31
# 6388  2C3F7AB0-D008-45A4-81A9-E92D9249010B    2020-09-20      01:24:31
#
#                                RX_FACILITY RX_FACILITY_TYPE  \
# 6384  URBAN - METROPOLITAN AREA CLINIC 261              NaN
# 6385  URBAN - METROPOLITAN AREA CLINIC 261              NaN
# 6386   URBAN - METROPOLITAN AREA CLINIC 42           CLINIC
# 6387   URBAN - METROPOLITAN AREA CLINIC 42           CLINIC
# 6388  URBAN - METROPOLITAN AREA CLINIC 261              NaN
#
#                  RX_URBAN_RURAL RX_FACILITY_SIZE  \
# 6384  URBAN - METROPOLITAN AREA              NaN
# 6385  URBAN - METROPOLITAN AREA              NaN
# 6386  URBAN - METROPOLITAN AREA              NaN
# 6387  URBAN - METROPOLITAN AREA              NaN
# 6388  URBAN - METROPOLITAN AREA              NaN
#
#                                    RX_DEPT RX_PROV_TAXON  ...  \
# 6384  URBAN - METROPOLITAN AREA CLINIC 261   DERMATOLOGY  ...
# 6385  URBAN - METROPOLITAN AREA CLINIC 261   DERMATOLOGY  ...
# 6386   URBAN - METROPOLITAN AREA CLINIC 42   DERMATOLOGY  ...
# 6387   URBAN - METROPOLITAN AREA CLINIC 42   DERMATOLOGY  ...
# 6388  URBAN - METROPOLITAN AREA CLINIC 261   DERMATOLOGY  ...
#
#             RX_BRAND_NAME      RX_GENERIC_NAME RX_ROUTE RX_STRENGTH  RX_UNIT  \
# 6384         ISOTRETINOIN         ISOTRETINOIN     ORAL          40     MG/1
# 6385  DOXYCYCLINE HYCLATE  DOXYCYCLINE HYCLATE     ORAL          50     MG/1
# 6386  DOXYCYCLINE HYCLATE  DOXYCYCLINE HYCLATE     ORAL          50     MG/1
# 6387               ALDARA            IMIQUIMOD  TOPICAL          50     MG/G
# 6388               ALDARA            IMIQUIMOD  TOPICAL          50     MG/G
#
#                 RX_DOSE_FORM  DATA_SUPPLIER_ID  \
# 6384  CAPSULE, LIQUID FILLED              4632
# 6385     TABLET, FILM COATED              4632
# 6386     TABLET, FILM COATED              2750
# 6387                   CREAM              2750
# 6388                   CREAM              4632
#
#                                        PRODUCT_NAME  PRODUCT_VERSION  \
# 6384  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS              5.0
# 6385  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS              5.0
# 6386  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS              5.0
# 6387  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS              5.0
# 6388  ALOPECIA_AREATA_SUBSAMPLE_PRESCRIPTION_ORDERS              5.0
#
#      EXPORT_DATE
# 6384    20231213
# 6385    20231213
# 6386    20231213
# 6387    20231213
# 6388    20231213
#
# [5 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6389 entries, 0 to 6388
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         6389 non-null   object
#  1   ENCOUNTER_ID       6389 non-null   object
#  2   RX_ORDER_DATE      6388 non-null   object
#  3   RX_ORDER_TIME      6388 non-null   object
#  4   RX_FACILITY        4917 non-null   object
#  5   RX_FACILITY_TYPE   4105 non-null   object
#  6   RX_URBAN_RURAL     5740 non-null   object
#  7   RX_FACILITY_SIZE   270 non-null    object
#  8   RX_DEPT            4917 non-null   object
#  9   RX_PROV_TAXON      6114 non-null   object
#  10  RX_PROV_ID         6116 non-null   object
#  11  RX_HCS_NDC         6070 non-null   object
#  12  RX_HCS_BRAND_NAME  5986 non-null   object
#  13  RX_DOSE            1102 non-null   object
#  14  RX_QUANTITY        6072 non-null   float64
#  15  RX_FREQ            2500 non-null   object
#  16  RX_REFILLS         6073 non-null   float64
#  17  RX_ORDER_SETTING   3749 non-null   object
#  18  RX_INSTR           6389 non-null   int64
#  19  RX_STATUS          6248 non-null   object
#  20  RX_STOP_REASON     496 non-null    object
#  21  RX_START_DATE      4082 non-null   object
#  22  RX_START_TIME      4082 non-null   object
#  23  RX_END_DATE        419 non-null    object
#  24  RX_END_TIME        419 non-null    object
#  25  RX_PKG_DESC        5640 non-null   object
#  26  RX_NDC             5726 non-null   object
#  27  RX_LABELER         5726 non-null   object
#  28  RX_BRAND_NAME      5726 non-null   object
#  29  RX_GENERIC_NAME    5724 non-null   object
#  30  RX_ROUTE           5696 non-null   object
#  31  RX_STRENGTH        5698 non-null   object
#  32  RX_UNIT            5698 non-null   object
#  33  RX_DOSE_FORM       5726 non-null   object
#  34  DATA_SUPPLIER_ID   6389 non-null   int64
#  35  PRODUCT_NAME       6389 non-null   object
#  36  PRODUCT_VERSION    6389 non-null   float64
#  37  EXPORT_DATE        6389 non-null   int64
# dtypes: float64(3), int64(3), object(32)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Checking for Duplication

# %%
data.nunique()
# Out:
# PATIENT_ID            838
# ENCOUNTER_ID         4192
# RX_ORDER_DATE        1450
# RX_ORDER_TIME        4382
# RX_FACILITY           285
# RX_FACILITY_TYPE        4
# RX_URBAN_RURAL          3
# RX_FACILITY_SIZE        2
# RX_DEPT               300
# RX_PROV_TAXON          20
# RX_PROV_ID            746
# RX_HCS_NDC            994
# RX_HCS_BRAND_NAME     654
# RX_DOSE               124
# RX_QUANTITY           104
# RX_FREQ                71
# RX_REFILLS             13
# RX_ORDER_SETTING        4
# RX_INSTR                1
# RX_STATUS               9
# RX_STOP_REASON         28
# RX_START_DATE        1257
# RX_START_TIME         573
# RX_END_DATE           178
# RX_END_TIME           152
# RX_PKG_DESC           845
# RX_NDC                742
# RX_LABELER            197
# RX_BRAND_NAME         334
# RX_GENERIC_NAME       228
# RX_ROUTE               20
# RX_STRENGTH           111
# RX_UNIT                43
# RX_DOSE_FORM           51
# DATA_SUPPLIER_ID        7
# PRODUCT_NAME            1
# PRODUCT_VERSION         1
# EXPORT_DATE             1
# dtype: int64

# %%
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [PATIENT_ID, ENCOUNTER_ID, RX_ORDER_DATE, RX_ORDER_TIME, RX_FACILITY, RX_FACILITY_TYPE, RX_URBAN_RURAL, RX_FACILITY_SIZE, RX_DEPT, RX_PROV_TAXON, RX_PROV_ID, RX_HCS_NDC, RX_HCS_BRAND_NAME, RX_DOSE, RX_QUANTITY, RX_FREQ, RX_REFILLS, RX_ORDER_SETTING, RX_INSTR, RX_STATUS, RX_STOP_REASON, RX_START_DATE, RX_START_TIME, RX_END_DATE, RX_END_TIME, RX_PKG_DESC, RX_NDC, RX_LABELER, RX_BRAND_NAME, RX_GENERIC_NAME, RX_ROUTE, RX_STRENGTH, RX_UNIT, RX_DOSE_FORM, DATA_SUPPLIER_ID, PRODUCT_NAME, PRODUCT_VERSION, EXPORT_DATE]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# No duplicate rows found!

# %% [markdown]
# ## Checking Missing Values

# %%
data.isnull().sum()
# Out:
# PATIENT_ID              0
# ENCOUNTER_ID            0
# RX_ORDER_DATE           1
# RX_ORDER_TIME           1
# RX_FACILITY          1472
# RX_FACILITY_TYPE     2284
# RX_URBAN_RURAL        649
# RX_FACILITY_SIZE     6119
# RX_DEPT              1472
# RX_PROV_TAXON         275
# RX_PROV_ID            273
# RX_HCS_NDC            319
# RX_HCS_BRAND_NAME     403
# RX_DOSE              5287
# RX_QUANTITY           317
# RX_FREQ              3889
# RX_REFILLS            316
# RX_ORDER_SETTING     2640
# RX_INSTR                0
# RX_STATUS             141
# RX_STOP_REASON       5893
# RX_START_DATE        2307
# RX_START_TIME        2307
# RX_END_DATE          5970
# RX_END_TIME          5970
# RX_PKG_DESC           749
# RX_NDC                663
# RX_LABELER            663
# RX_BRAND_NAME         663
# RX_GENERIC_NAME       665
# RX_ROUTE              693
# RX_STRENGTH           691
# RX_UNIT               691
# RX_DOSE_FORM          663
# DATA_SUPPLIER_ID        0
# PRODUCT_NAME            0
# PRODUCT_VERSION         0
# EXPORT_DATE             0
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# PATIENT_ID            0.000000
# ENCOUNTER_ID          0.000000
# RX_ORDER_DATE         0.015652
# RX_ORDER_TIME         0.015652
# RX_FACILITY          23.039599
# RX_FACILITY_TYPE     35.748943
# RX_URBAN_RURAL       10.158084
# RX_FACILITY_SIZE     95.773987
# RX_DEPT              23.039599
# RX_PROV_TAXON         4.304273
# RX_PROV_ID            4.272969
# RX_HCS_NDC            4.992957
# RX_HCS_BRAND_NAME     6.307716
# RX_DOSE              82.751604
# RX_QUANTITY           4.961653
# RX_FREQ              60.870246
# RX_REFILLS            4.946001
# RX_ORDER_SETTING     41.321021
# RX_INSTR              0.000000
# RX_STATUS             2.206918
# RX_STOP_REASON       92.236657
# RX_START_DATE        36.108937
# RX_START_TIME        36.108937
# RX_END_DATE          93.441853
# RX_END_TIME          93.441853
# RX_PKG_DESC          11.723274
# RX_NDC               10.377211
# RX_LABELER           10.377211
# RX_BRAND_NAME        10.377211
# RX_GENERIC_NAME      10.408515
# RX_ROUTE             10.846768
# RX_STRENGTH          10.815464
# RX_UNIT              10.815464
# RX_DOSE_FORM         10.377211
# DATA_SUPPLIER_ID      0.000000
# PRODUCT_NAME          0.000000
# PRODUCT_VERSION       0.000000
# EXPORT_DATE           0.000000
# dtype: float64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Checking for inconsistent data types

# %%
data_types = data.dtypes
print(data_types)
# Out:
# PATIENT_ID            object
# ENCOUNTER_ID          object
# RX_ORDER_DATE         object
# RX_ORDER_TIME         object
# RX_FACILITY           object
# RX_FACILITY_TYPE      object
# RX_URBAN_RURAL        object
# RX_FACILITY_SIZE      object
# RX_DEPT               object
# RX_PROV_TAXON         object
# RX_PROV_ID            object
# RX_HCS_NDC            object
# RX_HCS_BRAND_NAME     object
# RX_DOSE               object
# RX_QUANTITY          float64
# RX_FREQ               object
# RX_REFILLS           float64
# RX_ORDER_SETTING      object
# RX_INSTR               int64
# RX_STATUS             object
# RX_STOP_REASON        object
# RX_START_DATE         object
# RX_START_TIME         object
# RX_END_DATE           object
# RX_END_TIME           object
# RX_PKG_DESC           object
# RX_NDC                object
# RX_LABELER            object
# RX_BRAND_NAME         object
# RX_GENERIC_NAME       object
# RX_ROUTE              object
# RX_STRENGTH           object
# RX_UNIT               object
# RX_DOSE_FORM          object
# DATA_SUPPLIER_ID       int64
# PRODUCT_NAME          object
# PRODUCT_VERSION      float64
# EXPORT_DATE            int64
# dtype: object
