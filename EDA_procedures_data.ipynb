# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /var/folders/3m/l0tyzx5j5lg1wtczpcc3ff8h0000gn/T/ipykernel_2341/1676706666.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('alopecia-areata-subsample/PROCEDURES/data_000000000000.csv',  delimiter="|", low_memory=False)

# %%
data.shape
# Out:
# (39581, 25)

# %%
data.head()
# Out:
#                              PATIENT_ID                          ENCOUNTER_ID  \
# 0  00018A45-52DD-4BEF-8870-C65A168F3974  3E351E7B-F75D-4F4B-95EF-508E018224C7
# 1  00018A45-52DD-4BEF-8870-C65A168F3974  3E351E7B-F75D-4F4B-95EF-508E018224C7
# 2  00018A45-52DD-4BEF-8870-C65A168F3974  3E351E7B-F75D-4F4B-95EF-508E018224C7
# 3  00018A45-52DD-4BEF-8870-C65A168F3974  3E351E7B-F75D-4F4B-95EF-508E018224C7
# 4  00018A45-52DD-4BEF-8870-C65A168F3974  3E351E7B-F75D-4F4B-95EF-508E018224C7
#
#   PX_ORDER_DATE PX_ORDER_TIME PX_SERVICE_DATE PX_SERVICE_TIME  \
# 0    2018-10-01      13:36:00      2018-10-01        13:36:00
# 1    2018-10-01      13:36:00      2018-10-01        13:36:00
# 2    2018-10-01      13:36:00      2018-10-01        13:36:00
# 3    2018-10-01      13:36:00      2018-10-01        13:36:00
# 4    2018-10-01      13:36:00      2018-10-01        13:36:00
#
#   PX_FACILITY_TYPE             PX_URBAN_RURAL PX_FACILITY_SIZE  \
# ...

# %%
data.tail()
# Out:
#                                  PATIENT_ID  \
# 39576  FFE410FD-A1A0-45C1-AEE9-832016BFCFA9
# 39577  FFE410FD-A1A0-45C1-AEE9-832016BFCFA9
# 39578  FFE5DF19-0C98-43B6-96DA-D0ADCF740580
# 39579  FFE5DF19-0C98-43B6-96DA-D0ADCF740580
# 39580  FFE5DF19-0C98-43B6-96DA-D0ADCF740580
#
#                                ENCOUNTER_ID PX_ORDER_DATE PX_ORDER_TIME  \
# 39576  F70AEC9F-02AE-4132-BAD2-F56DBF943413    2022-12-14      15:20:00
# 39577  F70AEC9F-02AE-4132-BAD2-F56DBF943413    2022-12-14      15:20:00
# 39578  98EB1687-8972-41C2-85C0-4FA926322A4F    2023-07-17      12:30:00
# 39579  98EB1687-8972-41C2-85C0-4FA926322A4F    2023-07-17      12:30:00
# 39580  98EB1687-8972-41C2-85C0-4FA926322A4F    2023-07-17      12:30:00
#
#       PX_SERVICE_DATE PX_SERVICE_TIME PX_FACILITY_TYPE  \
# 39576      2022-12-14        15:20:00              NaN
# 39577      2022-12-14        15:20:00              NaN
# 39578      2023-07-17        12:30:00              NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39581 entries, 0 to 39580
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PATIENT_ID          39581 non-null  object
#  1   ENCOUNTER_ID        39581 non-null  object
#  2   PX_ORDER_DATE       39561 non-null  object
#  3   PX_ORDER_TIME       39561 non-null  object
#  4   PX_SERVICE_DATE     39581 non-null  object
#  5   PX_SERVICE_TIME     39581 non-null  object
#  6   PX_FACILITY_TYPE    26915 non-null  object
#  7   PX_URBAN_RURAL      39400 non-null  object
#  8   PX_FACILITY_SIZE    66 non-null     object
#  9   PX_DEPT_NAME        32781 non-null  object
#  10  PX_AU_PROV_ID       1266 non-null   object
#  11  PX_AU_PROV_TAXON    1266 non-null   object
#  12  PX_BIL_PROV_ID      44 non-null     object
#  13  PX_BIL_PROV_TAXON   44 non-null     object
#  14  PX_PERF_PROV_ID     0 non-null      float64
# ...

# %% [raw]
# Large dataset- memory usage: 7.5+ MB

# %% [markdown]
# ## Checking for Duplication

# %%
data.nunique()
# Out:
# PATIENT_ID             998
# ENCOUNTER_ID          8032
# PX_ORDER_DATE         1676
# PX_ORDER_TIME         1443
# PX_SERVICE_DATE       1677
# PX_SERVICE_TIME       1444
# PX_FACILITY_TYPE         4
# PX_URBAN_RURAL           3
# PX_FACILITY_SIZE         2
# PX_DEPT_NAME           322
# PX_AU_PROV_ID           71
# PX_AU_PROV_TAXON         9
# PX_BIL_PROV_ID           6
# PX_BIL_PROV_TAXON        3
# PX_PERF_PROV_ID          0
# PX_PERF_PROV_TAXON       0
# PX_CODE                190
# PX_TYPE                  4
# PX_HCS_DESC            458
# PX_SHORT_DESC          159
# PX_LONG_DESC           185
# DATA_SUPPLIER_ID         8
# PRODUCT_NAME             1
# PRODUCT_VERSION          1
# EXPORT_DATE              1
# dtype: int64

# %%
duplicate_rows = data[data.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [PATIENT_ID, ENCOUNTER_ID, PX_ORDER_DATE, PX_ORDER_TIME, PX_SERVICE_DATE, PX_SERVICE_TIME, PX_FACILITY_TYPE, PX_URBAN_RURAL, PX_FACILITY_SIZE, PX_DEPT_NAME, PX_AU_PROV_ID, PX_AU_PROV_TAXON, PX_BIL_PROV_ID, PX_BIL_PROV_TAXON, PX_PERF_PROV_ID, PX_PERF_PROV_TAXON, PX_CODE, PX_TYPE, PX_HCS_DESC, PX_SHORT_DESC, PX_LONG_DESC, DATA_SUPPLIER_ID, PRODUCT_NAME, PRODUCT_VERSION, EXPORT_DATE]
# Index: []
#
# [0 rows x 25 columns]

# %% [raw]
# No duplicate rows found in the dataset

# %% [markdown]
# ## Checking Missing Values

# %%
data.isnull().sum()
# Out:
# PATIENT_ID                0
# ENCOUNTER_ID              0
# PX_ORDER_DATE            20
# PX_ORDER_TIME            20
# PX_SERVICE_DATE           0
# PX_SERVICE_TIME           0
# PX_FACILITY_TYPE      12666
# PX_URBAN_RURAL          181
# PX_FACILITY_SIZE      39515
# PX_DEPT_NAME           6800
# PX_AU_PROV_ID         38315
# PX_AU_PROV_TAXON      38315
# PX_BIL_PROV_ID        39537
# PX_BIL_PROV_TAXON     39537
# PX_PERF_PROV_ID       39581
# PX_PERF_PROV_TAXON    39581
# PX_CODE                   0
# PX_TYPE                   0
# PX_HCS_DESC           11752
# PX_SHORT_DESC         26650
# PX_LONG_DESC          26650
# DATA_SUPPLIER_ID          0
# PRODUCT_NAME              0
# PRODUCT_VERSION           0
# EXPORT_DATE               0
# dtype: int64

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# PATIENT_ID              0.000000
# ENCOUNTER_ID            0.000000
# PX_ORDER_DATE           0.050529
# PX_ORDER_TIME           0.050529
# PX_SERVICE_DATE         0.000000
# PX_SERVICE_TIME         0.000000
# PX_FACILITY_TYPE       32.000202
# PX_URBAN_RURAL          0.457290
# PX_FACILITY_SIZE       99.833253
# PX_DEPT_NAME           17.179960
# PX_AU_PROV_ID          96.801496
# PX_AU_PROV_TAXON       96.801496
# PX_BIL_PROV_ID         99.888836
# PX_BIL_PROV_TAXON      99.888836
# PX_PERF_PROV_ID       100.000000
# PX_PERF_PROV_TAXON    100.000000
# PX_CODE                 0.000000
# PX_TYPE                 0.000000
# PX_HCS_DESC            29.691013
# PX_SHORT_DESC          67.330285
# PX_LONG_DESC           67.330285
# DATA_SUPPLIER_ID        0.000000
# PRODUCT_NAME            0.000000
# PRODUCT_VERSION         0.000000
# EXPORT_DATE             0.000000
# dtype: float64

# %% [raw]
# Data Has Many Missing Values ! need to drop the column with all NaN values

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Checking for inconsistent data types

# %%
data_types = data.dtypes
print(data_types)
# Out:
# PATIENT_ID             object
# ENCOUNTER_ID           object
# PX_ORDER_DATE          object
# PX_ORDER_TIME          object
# PX_SERVICE_DATE        object
# PX_SERVICE_TIME        object
# PX_FACILITY_TYPE       object
# PX_URBAN_RURAL         object
# PX_FACILITY_SIZE       object
# PX_DEPT_NAME           object
# PX_AU_PROV_ID          object
# PX_AU_PROV_TAXON       object
# PX_BIL_PROV_ID         object
# PX_BIL_PROV_TAXON      object
# PX_PERF_PROV_ID       float64
# PX_PERF_PROV_TAXON    float64
# PX_CODE                object
# PX_TYPE                object
# PX_HCS_DESC            object
# PX_SHORT_DESC          object
# PX_LONG_DESC           object
# DATA_SUPPLIER_ID        int64
# PRODUCT_NAME           object
# PRODUCT_VERSION       float64
# EXPORT_DATE             int64
# dtype: object
